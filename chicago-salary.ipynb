# %%
import pandas as pd
import numpy as np

import streamlit as st
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
df = pd.read_csv('data/Current_Employee_Names__Salaries__and_Position_Titles_20250413.csv')

# %%
df.head()
# Out:
#                       Name                  Job Titles  \
# 0     VILLANUEVA, JENNIFER  STAFF ASST TO THE ALDERMAN
# 1   RUBI NAVARIJO, ANGEL A  STAFF ASST TO THE ALDERMAN
# 2  SERRITELLA JR, VICTOR A   EMERGENCY CREW DISPATCHER
# 3           AGUAYO, LUIS M        CONSTRUCTION LABORER
# 4         JACKSON, TIMOTHY                    WATCHMAN
#
#                        Department Full or Part-Time Salary or Hourly  \
# 0                    CITY COUNCIL                 F           SALARY
# 1                    CITY COUNCIL                 F           SALARY
# 2  DEPARTMENT OF WATER MANAGEMENT                 F           HOURLY
# 3  DEPARTMENT OF WATER MANAGEMENT                 F           HOURLY
# 4  DEPARTMENT OF WATER MANAGEMENT                 F           HOURLY
#
#    Typical Hours  Annual Salary  Hourly Rate
# 0            NaN        60000.0          NaN
# 1            NaN        70008.0          NaN
# 2           40.0            NaN        50.15
# ...

# %%
df.columns=['name', 'job_title', 'department', 'full_part_time', 'salary_hourly', 'typical_hours', 'annual_salary', 'hourly_rate']

# %%
df
# Out:
#                           name                   job_title  \
# 0         VILLANUEVA, JENNIFER  STAFF ASST TO THE ALDERMAN
# 1       RUBI NAVARIJO, ANGEL A  STAFF ASST TO THE ALDERMAN
# 2      SERRITELLA JR, VICTOR A   EMERGENCY CREW DISPATCHER
# 3               AGUAYO, LUIS M        CONSTRUCTION LABORER
# 4             JACKSON, TIMOTHY                    WATCHMAN
# ...                        ...                         ...
# 31965         PEREZ, ALEXANDER                    SERGEANT
# 31966       SHERIDAN, PATRICIA                    SERGEANT
# 31967            RUIZ, LEILA A                    SERGEANT
# 31968         SCHNIER, BRIAN T                    SERGEANT
# 31969        ALVARADO, IGNACIO                    SERGEANT
#
#                            department full_part_time salary_hourly  \
# 0                        CITY COUNCIL              F        SALARY
# 1                        CITY COUNCIL              F        SALARY
# ...

# %%
df['annual_pay']=np.where(df['salary_hourly']=='SALARY', df['annual_salary'],
                 np.where(df['salary_hourly']=='HOURLY', df['hourly_rate']*df['typical_hours']*50, 0)
                         )

# %%
# Out:
#                       name                   job_title  \
# 0     VILLANUEVA, JENNIFER  STAFF ASST TO THE ALDERMAN
# 1   RUBI NAVARIJO, ANGEL A  STAFF ASST TO THE ALDERMAN
# 2  SERRITELLA JR, VICTOR A   EMERGENCY CREW DISPATCHER
# 3           AGUAYO, LUIS M        CONSTRUCTION LABORER
# 4         JACKSON, TIMOTHY                    WATCHMAN
#
#                        department full_part_time salary_hourly  typical_hours  \
# 0                    CITY COUNCIL              F        SALARY            NaN
# 1                    CITY COUNCIL              F        SALARY            NaN
# 2  DEPARTMENT OF WATER MANAGEMENT              F        HOURLY           40.0
# 3  DEPARTMENT OF WATER MANAGEMENT              F        HOURLY           40.0
# 4  DEPARTMENT OF WATER MANAGEMENT              F        HOURLY           40.0
#
#    annual_salary  hourly_rate  annual_pay
# 0        60000.0          NaN     60000.0
# 1        70008.0          NaN     70008.0
# ...
